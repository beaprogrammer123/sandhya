# %%
import pandas as pd
import numpy as np

# %%
read_html=pd.read_html('https://en.wikipedia.org/wiki/Minnesota')
type(read_html)
# Out:
# list

# %%
for i in read_html:
  print(i)
# Out:
#                                             Minnesota                                        Minnesota.1
# 0                                               State                                              State
# 1                                  State of Minnesota                                 State of Minnesota
# 2   .mw-parser-output .ib-settlement-cols{text-ali...  .mw-parser-output .ib-settlement-cols{text-ali...
# 3   Nickname(s): Land of 10,000 Lakes;North Star S...  Nickname(s): Land of 10,000 Lakes;North Star S...
# 4   Motto(s): L'Étoile du Nord (French: The Star o...  Motto(s): L'Étoile du Nord (French: The Star o...
# 5                           Anthem: "Hail! Minnesota"                          Anthem: "Hail! Minnesota"
# 6   Map of the United States with Minnesota highli...  Map of the United States with Minnesota highli...
# 7                                             Country                                      United States
# ...

# %%
s1=pd.DataFrame(read_html[0])
s1
# Out:
#                                             Minnesota                                        Minnesota.1
# 0                                               State                                              State
# 1                                  State of Minnesota                                 State of Minnesota
# 2   .mw-parser-output .ib-settlement-cols{text-ali...  .mw-parser-output .ib-settlement-cols{text-ali...
# 3   Nickname(s): Land of 10,000 Lakes;North Star S...  Nickname(s): Land of 10,000 Lakes;North Star S...
# 4   Motto(s): L'Étoile du Nord (French: The Star o...  Motto(s): L'Étoile du Nord (French: The Star o...
# 5                           Anthem: "Hail! Minnesota"                          Anthem: "Hail! Minnesota"
# 6   Map of the United States with Minnesota highli...  Map of the United States with Minnesota highli...
# 7                                             Country                                      United States
# ...

# %%
s2=pd.DataFrame(read_html[1])
s2
# Out:
#                  Minnesota state symbols
#                          Living insignia                                  Living insignia.1
# 0                                   Bird                                        Common loon
# 1                              Butterfly                                            Monarch
# 2                                   Fish                                            Walleye
# 3                                 Flower                      Pink-and-white lady's slipper
# 4                               Mushroom                 Common morel (Morchella esculenta)
# 5                                   Tree                                     Norway pine[7]
# 6                     Inanimate insignia                                 Inanimate insignia
# 7                               Beverage                                               Milk
# 8                                   Food  Fruit: Honeycrisp appleMuffin: BlueberryMushro...
# ...

# %%
s3=pd.DataFrame(read_html[2])
s3
# Out:
#               Location July (°F) July (°C) January (°F) January (°C)
# 0          Minneapolis     83/64     28/18         23/7       −4/−13
# 1           Saint Paul     83/63     28/17         23/6       −5/−14
# 2            Rochester     82/63     28/17         23/3       −5/−16
# 3               Duluth     76/55     24/13         19/1       −7/−17
# 4            St. Cloud     81/58     27/14        18/−1       −7/−18
# 5              Mankato     86/62     30/16         23/3       −5/−16
# 6  International Falls     77/52     25/11        15/−6       −9/−21

# %%
s4=pd.DataFrame(read_html[4])

# %%
s4
# Out:
#             Race and Ethnicity[80]  Alone  Alone.1  Total  Total.1
# 0             White (non-Hispanic)  76.3%      NaN  80.2%      NaN
# 1  African American (non-Hispanic)   6.9%      NaN   8.2%      NaN
# 2            Hispanic or Latino[a]      —      NaN   6.1%      NaN
# 3                            Asian   5.2%      NaN   6.2%      NaN
# 4                  Native American   1.0%      NaN   2.3%      NaN
# 5                 Pacific Islander  0.05%      NaN   0.1%      NaN
# 6                            Other   0.4%      NaN   1.3%      NaN

# %%
s4.fillna(" ",inplace=False)
s4
# Out:
#             Race and Ethnicity[80]  Alone  Alone.1  Total  Total.1
# 0             White (non-Hispanic)  76.3%      NaN  80.2%      NaN
# 1  African American (non-Hispanic)   6.9%      NaN   8.2%      NaN
# 2            Hispanic or Latino[a]      —      NaN   6.1%      NaN
# 3                            Asian   5.2%      NaN   6.2%      NaN
# 4                  Native American   1.0%      NaN   2.3%      NaN
# 5                 Pacific Islander  0.05%      NaN   0.1%      NaN
# 6                            Other   0.4%      NaN   1.3%      NaN

# %%
s4.replace(np.nan,'')
s4.drop(['Alone.1', 'Total.1'],axis = 1)
# Out:
#             Race and Ethnicity[80]  Alone  Total
# 0             White (non-Hispanic)  76.3%  80.2%
# 1  African American (non-Hispanic)   6.9%   8.2%
# 2            Hispanic or Latino[a]      —   6.1%
# 3                            Asian   5.2%   6.2%
# 4                  Native American   1.0%   2.3%
# 5                 Pacific Islander  0.05%   0.1%
# 6                            Other   0.4%   1.3%

# %%
s5=pd.DataFrame(read_html[5])
s5
# Out:
#                       Affiliation  % of population  % of population.1
# 0                       Christian               74                NaN
# 1                      Protestant               50                NaN
# 2                        Lutheran               26                NaN
# 3                       Methodist                3                NaN
# 4                     Pentecostal                3                NaN
# 5   Historically Black Protestant                2                NaN
# 6                Other Protestant               16                NaN
# 7                  Roman Catholic               22                NaN
# 8                          Mormon                1                NaN
# 9                 Other Christian                1                NaN
# 10  Other religion or association                5                NaN
# 11                        Judaism                1                NaN
# ...

# %%
s5.fillna(" ",inplace=False)
s5
# Out:
#                       Affiliation  % of population  % of population.1
# 0                       Christian               74                NaN
# 1                      Protestant               50                NaN
# 2                        Lutheran               26                NaN
# 3                       Methodist                3                NaN
# 4                     Pentecostal                3                NaN
# 5   Historically Black Protestant                2                NaN
# 6                Other Protestant               16                NaN
# 7                  Roman Catholic               22                NaN
# 8                          Mormon                1                NaN
# 9                 Other Christian                1                NaN
# 10  Other religion or association                5                NaN
# 11                        Judaism                1                NaN
# ...

# %%
s5.replace(np.nan,'')
s5.drop(['% of population.1'],axis = 1)
# Out:
#                       Affiliation  % of population
# 0                       Christian               74
# 1                      Protestant               50
# 2                        Lutheran               26
# 3                       Methodist                3
# 4                     Pentecostal                3
# 5   Historically Black Protestant                2
# 6                Other Protestant               16
# 7                  Roman Catholic               22
# 8                          Mormon                1
# 9                 Other Christian                1
# 10  Other religion or association                5
# 11                        Judaism                1
# 12                          Islam                1
# 13          Other and unspecified                3
# 14                   Unaffiliated               20
# 15          Nothing in particular               13
# 16                       Agnostic                4
# ...

# %%
frames = [ s3, s4]
result = pd.concat(frames)
print(result)
# Out:
#               Location July (°F) July (°C)  ... Alone.1  Total Total.1
# 0          Minneapolis     83/64     28/18  ...     NaN    NaN     NaN
# 1           Saint Paul     83/63     28/17  ...     NaN    NaN     NaN
# 2            Rochester     82/63     28/17  ...     NaN    NaN     NaN
# 3               Duluth     76/55     24/13  ...     NaN    NaN     NaN
# 4            St. Cloud     81/58     27/14  ...     NaN    NaN     NaN
# 5              Mankato     86/62     30/16  ...     NaN    NaN     NaN
# 6  International Falls     77/52     25/11  ...     NaN    NaN     NaN
# 0                  NaN       NaN       NaN  ...     NaN  80.2%     NaN
# 1                  NaN       NaN       NaN  ...     NaN   8.2%     NaN
# 2                  NaN       NaN       NaN  ...     NaN   6.1%     NaN
# 3                  NaN       NaN       NaN  ...     NaN   6.2%     NaN
# 4                  NaN       NaN       NaN  ...     NaN   2.3%     NaN
# ...

# %%
result.replace(np.nan,' ',regex=True)
# Out:
#               Location July (°F) July (°C)  ... Alone.1  Total Total.1
# 0          Minneapolis     83/64     28/18  ...
# 1           Saint Paul     83/63     28/17  ...
# 2            Rochester     82/63     28/17  ...
# 3               Duluth     76/55     24/13  ...
# 4            St. Cloud     81/58     27/14  ...
# 5              Mankato     86/62     30/16  ...
# 6  International Falls     77/52     25/11  ...
# 0                                           ...          80.2%
# 1                                           ...           8.2%
# 2                                           ...           6.1%
# 3                                           ...           6.2%
# 4                                           ...           2.3%
# 5                                           ...           0.1%
# 6                                           ...           1.3%
#
# [14 rows x 10 columns]

# %%
#PDF
from pandas import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install tabula-py
# Out:
# ...
#      |████████████████████████████████| 12.0 MB 19.9 MB/s
# ...

# %%
from tabula import read_pdf
df = read_pdf('/content/drive/MyDrive/architects1.pdf',pages=(1,2,3,4,5),multiple_tables=False,stream=False)
# Out:
# Got stderr: Feb 16, 2022 3:03:19 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Feb 16, 2022 3:03:19 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Feb 16, 2022 3:03:19 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 17 fonts

# %%
for i in df:
  print(i,1)
  len(df)
# Out:
#    S.No  ...                                    Contact Details
# 0    1.  ...  Tel: 95120-5321278\r9818290708\rEmail: info@st...
# 1    2.  ...      Tel: 033-24740570-73\rEmail: jpamnl@gmail.com
# 2    3.  ...  Tel: 27457241\r23857061, 23857824\rFax: 238590...
# 3    4.  ...  Tel: 24682100/ 41504900 extn.2139\r\rEmail: mi...
# 4    5.  ...             Tel: 95124-4065318\rFax: 95124-2352829
# ..  ...  ...                                                ...
# 74  33.  ...  Tel : 0484-2537668, 2538445/\r09847322048\rFax...
# 75  34.  ...  Tel :022- 28695274/ 32522539/\r09870672649/ 50...
# 76  35.  ...  Tel : 022- 25832222\rFax: 91-22-25838408\rEmai...
# 77  36.  ...  Tel: 0191-2560043\rFax : 0191- 2560043\rEmail:...
# 78  37.  ...  Tel: 022- 28902248\rFax : 022-28912522\rEmail:...
#
# [79 rows x 4 columns] 1

# %%
data=DataFrame(df[0])
data
# Out:
#    S.No  ...                                    Contact Details
# 0    1.  ...  Tel: 95120-5321278\r9818290708\rEmail: info@st...
# 1    2.  ...      Tel: 033-24740570-73\rEmail: jpamnl@gmail.com
# 2    3.  ...  Tel: 27457241\r23857061, 23857824\rFax: 238590...
# 3    4.  ...  Tel: 24682100/ 41504900 extn.2139\r\rEmail: mi...
# 4    5.  ...             Tel: 95124-4065318\rFax: 95124-2352829
# ..  ...  ...                                                ...
# 74  33.  ...  Tel : 0484-2537668, 2538445/\r09847322048\rFax...
# 75  34.  ...  Tel :022- 28695274/ 32522539/\r09870672649/ 50...
# 76  35.  ...  Tel : 022- 25832222\rFax: 91-22-25838408\rEmai...
# 77  36.  ...  Tel: 0191-2560043\rFax : 0191- 2560043\rEmail:...
# 78  37.  ...  Tel: 022- 28902248\rFax : 022-28912522\rEmail:...
#
# [79 rows x 4 columns]

# %%
df1 = data.iloc[ :9]
df1
# Out:
#   S.No  ...                                    Contact Details
# 0   1.  ...  Tel: 95120-5321278\r9818290708\rEmail: info@st...
# 1   2.  ...      Tel: 033-24740570-73\rEmail: jpamnl@gmail.com
# 2   3.  ...  Tel: 27457241\r23857061, 23857824\rFax: 238590...
# 3   4.  ...  Tel: 24682100/ 41504900 extn.2139\r\rEmail: mi...
# 4   5.  ...             Tel: 95124-4065318\rFax: 95124-2352829
# 5   6.  ...  Tel : 0522-2209241\rEmail : civilconsultants@y...
# 6   7.  ...       Tel: 9958170019\rEmail: Alpana@kalpakrit.com
# 7   8.  ...  Tel: 41655696/\rMobile: 9910441016\rFax: 41655...
# 8   9.  ...  Tel : 23922108\rFax : 23918936\rEmail: ablarch...
#
# [9 rows x 4 columns]

# %%
df2=data.iloc[9:58]
df2['List of Architects'] = df2['S.No']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2['S.No'] = ' '
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2=df2.dropna()
df2
# Out:
#    S.No          List of Architects       State              Contact Details
# 18       12.  Shri. Tanmay Tathagat   New Delhi                Tel: 46065081
# 27          14.  Shri. Uday B Kapre   New Delhi     Tel : 26132076/ 26894055
# 33          15.  Mr Sanjay  Udamale      Mumbai           Tel :022- 25346197
# 39           16. 0Mr Surinder Bagha  Chandigarh  Tel : 0172-2722466/ 3043466
# 45               17.  Ms. Tara Dhal   Bhubanesh  Tel : 0674-2397386/ 2397318
# 46                 The Design Group         war            Fax: 067-42397318
# 50           18.  Shri. Vicky Rawat    Debradun           Tel : 0135-2762276

# %%
df2=data.iloc[9:58]
df2['List of Architects']=df2['S.No']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2['S.No']= ' '
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2=df2.dropna()
df2
# Out:
#    S.No List of Architects       State              Contact Details
# 18                           New Delhi                Tel: 46065081
# 27                           New Delhi     Tel : 26132076/ 26894055
# 33                              Mumbai           Tel :022- 25346197
# 39                          Chandigarh  Tel : 0172-2722466/ 3043466
# 45                           Bhubanesh  Tel : 0674-2397386/ 2397318
# 46                                 war            Fax: 067-42397318
# 50                            Debradun           Tel : 0135-2762276

# %%
df3=data.iloc[58:]
df3=df3.dropna()
df3
# Out:
#    S.No  ...                                    Contact Details
# 58  19.  ...  Tel: 020-26053003\rFax no: 20 26131755\rEmail ...
# 59  20.  ...  Tel : 24112391/ 92\rFax no: 46016239\rIntegral...
# 60  21.  ...  Tel : 0141- 4099621-23\rFax :01412373180\rrish...
# 61  22.  ...  Tel : (044) 24450655/ 45504313\rjuzer@conserve...
# 62  23.  ...  Tel : 0484-4072000  to 4072099\rFax : 91-484-4...
# 63  24.  ...  Tel:9310010460\rFax : 011 46082355\rVandanagar...
# 64  25.  ...  Tel : 0141- 2520352/ 3270181\rFax: 91-141-2520...
# 66  26.  ...  Tel: 022-67939388/ 89\rFax: 022-67939390\rbalb...
# 67  27.  ...  Tel :011- 26274672\rFax: 011-26273098\rlivin@a...
# 68  28.  ...  Tel : 0141- 2741664, 2741232\rFax: 91-141-2741...
# 69  29.  ...  Tel :080-40494000\rFax: 91-80-40494299\rdeepak...
# 70  30.  ...  Tel : 95120- 2400345\rFax :\r\rarchitectatul@g...
# 71  31.  ...  Tel : 044- 24991676\rcrn@crn.co.in,\rFax: 91-4...
# 72  32.  ...                          Tel: 022- 27831070/ 72/61
# ...

# %%
data1 = [df1,df2,df3]
final=pd.concat(data1)
final
# Out:
#    S.No  ...                                    Contact Details
# 0    1.  ...  Tel: 95120-5321278\r9818290708\rEmail: info@st...
# 1    2.  ...      Tel: 033-24740570-73\rEmail: jpamnl@gmail.com
# 2    3.  ...  Tel: 27457241\r23857061, 23857824\rFax: 238590...
# 3    4.  ...  Tel: 24682100/ 41504900 extn.2139\r\rEmail: mi...
# 4    5.  ...             Tel: 95124-4065318\rFax: 95124-2352829
# 5    6.  ...  Tel : 0522-2209241\rEmail : civilconsultants@y...
# 6    7.  ...       Tel: 9958170019\rEmail: Alpana@kalpakrit.com
# 7    8.  ...  Tel: 41655696/\rMobile: 9910441016\rFax: 41655...
# 8    9.  ...  Tel : 23922108\rFax : 23918936\rEmail: ablarch...
# 18       ...                                      Tel: 46065081
# 27       ...                           Tel : 26132076/ 26894055
# 33       ...                                 Tel :022- 25346197
# 39       ...                        Tel : 0172-2722466/ 3043466
# 45       ...                        Tel : 0674-2397386/ 2397318
# ...

# %%
data.set_index('S.No')
data
# Out:
#    S.No  ...                                    Contact Details
# 0    1.  ...  Tel: 95120-5321278\r9818290708\rEmail: info@st...
# 1    2.  ...      Tel: 033-24740570-73\rEmail: jpamnl@gmail.com
# 2    3.  ...  Tel: 27457241\r23857061, 23857824\rFax: 238590...
# 3    4.  ...  Tel: 24682100/ 41504900 extn.2139\r\rEmail: mi...
# 4    5.  ...             Tel: 95124-4065318\rFax: 95124-2352829
# ..  ...  ...                                                ...
# 74  33.  ...  Tel : 0484-2537668, 2538445/\r09847322048\rFax...
# 75  34.  ...  Tel :022- 28695274/ 32522539/\r09870672649/ 50...
# 76  35.  ...  Tel : 022- 25832222\rFax: 91-22-25838408\rEmai...
# 77  36.  ...  Tel: 0191-2560043\rFax : 0191- 2560043\rEmail:...
# 78  37.  ...  Tel: 022- 28902248\rFax : 022-28912522\rEmail:...
#
# [79 rows x 4 columns]

# %%
data.fillna("",inplace=True)
data
# Out:
#    S.No  ...                                    Contact Details
# 0    1.  ...  Tel: 95120-5321278\r9818290708\rEmail: info@st...
# 1    2.  ...      Tel: 033-24740570-73\rEmail: jpamnl@gmail.com
# 2    3.  ...  Tel: 27457241\r23857061, 23857824\rFax: 238590...
# 3    4.  ...  Tel: 24682100/ 41504900 extn.2139\r\rEmail: mi...
# 4    5.  ...             Tel: 95124-4065318\rFax: 95124-2352829
# ..  ...  ...                                                ...
# 74  33.  ...  Tel : 0484-2537668, 2538445/\r09847322048\rFax...
# 75  34.  ...  Tel :022- 28695274/ 32522539/\r09870672649/ 50...
# 76  35.  ...  Tel : 022- 25832222\rFax: 91-22-25838408\rEmai...
# 77  36.  ...  Tel: 0191-2560043\rFax : 0191- 2560043\rEmail:...
# 78  37.  ...  Tel: 022- 28902248\rFax : 022-28912522\rEmail:...
#
# [79 rows x 4 columns]

# %%
for i in range(9,57):
  data.loc[i,'S.No':'List of Architects']=data.loc[i,'S.No':'List of Architects'].shift()
data
# Out:
#    S.No  ...                                    Contact Details
# 0    1.  ...  Tel: 95120-5321278\r9818290708\rEmail: info@st...
# 1    2.  ...      Tel: 033-24740570-73\rEmail: jpamnl@gmail.com
# 2    3.  ...  Tel: 27457241\r23857061, 23857824\rFax: 238590...
# 3    4.  ...  Tel: 24682100/ 41504900 extn.2139\r\rEmail: mi...
# 4    5.  ...             Tel: 95124-4065318\rFax: 95124-2352829
# ..  ...  ...                                                ...
# 74  33.  ...  Tel : 0484-2537668, 2538445/\r09847322048\rFax...
# 75  34.  ...  Tel :022- 28695274/ 32522539/\r09870672649/ 50...
# 76  35.  ...  Tel : 022- 25832222\rFax: 91-22-25838408\rEmai...
# 77  36.  ...  Tel: 0191-2560043\rFax : 0191- 2560043\rEmail:...
# 78  37.  ...  Tel: 022- 28902248\rFax : 022-28912522\rEmail:...
#
# [79 rows x 4 columns]

# %%
import numpy

# %%
import numpy as sk

# %%
arr = np.array([1, 2, 3, 4, 5])
x = arr.copy()
arr[0] = 42

# %%
print(arr)
print(x)
# Out:
# [42  2  3  4  5]
# [1 2 3 4 5]
